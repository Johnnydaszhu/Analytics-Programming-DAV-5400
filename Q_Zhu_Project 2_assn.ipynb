# %% [markdown]
# # Kickstarter Analysis
#
# ### Randy(Qinghao) Xia
# ### Jonney(Qihua) Zhu

# %% [markdown]
# ## Part 1: Introduction

# %% [markdown]
# Since the Kickstarter Campaigns getting more successful and widely known. More “Kickstarters” start to use the platform to gain the pledges as the startup capital for the business. In order to increase the success rate of the campaign, the platform hires the data analysis team to analyze the database that contains the information of more than 193,000 participants.
#
# After the analysis and evaluation process, the data analysis team should be able to ask and answers several questions and come up with some suggestions that the platform could give to the “Kickstarter” to increase the success rate of pledge program.
#
# The data type in the data set include:
#
# integer, float, and string.
#
# Research Question:
#
# 1. How different country behave differently in success rate?
# 2. Is there any relationship between the goal amount and pledged amount among the succeed cases？
# 3. How Main Category Perform differently on average amount of usd pledged ending in different quarter?

# %% [markdown]
# ## Part 2: Data Summary

# %% [markdown]
# Explain where you acquired your data from; how many use cases your data set provides; how many attributes are in each use case; what the data types are for each of the attributes; etc.
#
# The data team find the data set from the website of  Kickstarter. The link of the data set download is : [https://www.kaggle.com/yashkantharia/kickstarter-campaigns](https://www.kaggle.com/yashkantharia/kickstarter-campaigns)
#
# According to the data set there are 20 atrributes with 3 different data types, and they are:
#
# 1. id, Integer
# 2. name, string
# 3. currency, string
# 4. main_category, string
# 5. sub_category, sting
# 6. lanunched_at, string
# 7. deadline, string
# 8. duration, float
# 9. goal_used, float
# 10. city , string
# 11. state, string
# 12. country, string
# 13. blurb_length, integer
# 14. name_length, integer
# 15. status, string
# 16. start_month, integer
# 17. end_month, integer
# 18. start_Q string
# 19. end_Q, string
# 20. usd_pledged, float

# %%
# Import the libraries needed.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the file
df = pd.read_csv('https://raw.githubusercontent.com/Johnnydaszhu/DAV-5400/master/Kickstarter_projects_Feb19.csv')

df
# Out:
#                 id                                               name  \
# 0       1687733153              Socks of Speed and Socks of Elvenkind
# 1        227936657   Power Punch Boot Camp: An All-Ages Graphic Novel
# 2        454186436         Live Printing with SX8: "Squeegee Pulp Up"
# 3        629469071                  Lost Dog Street Band's Next Album
# 4        183973060                              Qto-X, a Tiny Lantern
# 5        122409435                        Aaron McDonnell EP "Follow"
# 6        421029848                                          Lush Life
# 7       1452339343  The biggest NASA fashion collection in the gal...
# 8        815131323                                    The Nothing Box
# 9       2132215273  "Sittin' 'round waitin' for the world to end" ...
# 10          390870                      Those White Horses - Issue #1
# 11       209032207  Fenton Fox--Boutique Swimwear Amazingness from...
# ...

# %%
# Use the "pd.dtypes" functin to see the data types of each attribute.
df.dtypes
# Out:
# id                 int64
# name              object
# currency          object
# main_category     object
# sub_category      object
# launched_at       object
# deadline          object
# duration         float64
# goal_usd         float64
# city              object
# state             object
# country           object
# blurb_length       int64
# name_length        int64
# status            object
# start_month        int64
# end_month          int64
# start_Q           object
# end_Q             object
# usd_pledged      float64
# dtype: object

# %% [markdown]
# ## Part 3: Exploratory Data Analysis (EDA)

# %% [markdown]
# Provide summary statistics for each attribute; provide appropriate graphical
# analysis for each attribute using both Matplotlib and Seaborn. For example, if you believe it is appropriate to generate a
# histogram for a particular variable as part of your EDA, create it first using Matplotlib and then once again using
# Seaborn. Include a narrative describing your EDA findings.
#
# After acquiring data set and gain a basic understanding of it, the data analysis team load the data between April 2009 and Feb 2019 and doing some general and correlation test to identify the insights. (Use "pd.describe", and "pd.corr"). After the basic and correlation analysis, the team found that:

# %%
# Test if we did correctly.
df.head()
# Out:
#            id                                              name currency  \
# 0  1687733153             Socks of Speed and Socks of Elvenkind      USD
# 1   227936657  Power Punch Boot Camp: An All-Ages Graphic Novel      GBP
# 2   454186436        Live Printing with SX8: "Squeegee Pulp Up"      USD
# 3   629469071                 Lost Dog Street Band's Next Album      USD
# 4   183973060                             Qto-X, a Tiny Lantern      USD
#
#   main_category    sub_category          launched_at             deadline  \
# 0         games  Tabletop Games  2018-10-30 20:00:02  2018-11-15 17:59:00
# 1        comics     Comic Books  2018-08-06 10:00:43  2018-09-05 10:00:43
# 2       fashion         Apparel  2017-06-09 15:41:03  2017-07-09 15:41:03
# 3         music  Country & Folk  2014-09-25 18:46:01  2014-11-10 06:00:00
# 4    technology         Gadgets  2016-11-28 16:35:11  2017-01-27 16:35:11
#
#    duration     goal_usd        city    state country  blurb_length  \
# ...

# %%
# Use the "pd.describe" function to do basic analysis.
df.describe(include='all')
# Out:
#                   id                       name currency main_category  \
# count   1.925480e+05                     192548   192548        192548
# unique           NaN                     167953       14            15
# top              NaN  A Midsummer Night's Dream      USD         music
# freq             NaN                          7   137845         25850
# mean    1.072709e+09                        NaN      NaN           NaN
# std     6.194810e+08                        NaN      NaN           NaN
# min     8.624000e+03                        NaN      NaN           NaN
# 25%     5.348591e+08                        NaN      NaN           NaN
# 50%     1.074643e+09                        NaN      NaN           NaN
# 75%     1.607955e+09                        NaN      NaN           NaN
# max     2.147476e+09                        NaN      NaN           NaN
#
#        sub_category          launched_at             deadline       duration  \
# ...

# %% [markdown]
# From the description table above there are some insights raised:
#
# 1. There are a total of 192,548 participants in the data set.
# 2. The average duration of the project is around 33 days with a standard deviation of 12 days.
# 3. The minimum duration of the project is 1 day, and the maximum duration is 93 days.
# 4. Los Angeles is the most favorite city, California is the most favorite State, and the U.S. is the most favorite country for the "Kickstarters".
# 5. There are 14 different currencies are used in the platform.
# 6. Most projects tend to launch in the third quarter, and ended in the fourth quarter.
# 7. The Average blurb length of the description of the project is around 19-word blocks with the standard deviation of 5-word blocks.
# 8. The Average name length of the project is around 6 words with a standard deviation of 3 words.
# 9. The average goal used for a project is 37,049.9 dollars, and the average pledge amount is 13,711.66 dollars.
# 10. The maximum goal amount and pledged amounts are 129 million dollars and 8.6 million dollars.

# %%
# Use the "df.corr" to see the corrlation between variables.
df.corr()
# Out:
#                     id  duration  goal_usd  blurb_length  name_length  \
# id            1.000000  0.003787  0.001370     -0.000418    -0.007221
# duration      0.003787  1.000000  0.026188      0.031181    -0.016826
# goal_usd      0.001370  0.026188  1.000000     -0.002095    -0.005263
# blurb_length -0.000418  0.031181 -0.002095      1.000000     0.136685
# name_length  -0.007221 -0.016826 -0.005263      0.136685     1.000000
# start_month  -0.000726  0.007794  0.002996     -0.039289     0.011408
# end_month    -0.001530 -0.026497  0.000176     -0.029991     0.018236
# usd_pledged  -0.002153  0.025177  0.007992     -0.007005     0.052457
#
#               start_month  end_month  usd_pledged
# id              -0.000726  -0.001530    -0.002153
# duration         0.007794  -0.026497     0.025177
# goal_usd         0.002996   0.000176     0.007992
# blurb_length    -0.039289  -0.029991    -0.007005
# name_length      0.011408   0.018236     0.052457
# ...

# %% [markdown]
# The correlation table shows:
#
# 1. The correlations between each variable look very weak in general.
# 2. There is a relatively strong correlation between the start month and end month.

# %%
# Slice the series of 'usd_pledged', and 'goal_usd' within successful cases.
dfg = df[['usd_pledged','goal_usd']]
dfg.head(5)

# Draw a scatter plot use seaborn 'sns.lmplot' function.
bx = sns.lmplot(x= 'usd_pledged', y='goal_usd', data=dfg)
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Setup the figue.
plt.figure(1)

# Draw a scatter plot with x = 'usd_pledged', and y = 'goal_usd' 
plt.scatter(dfg.usd_pledged,dfg.goal_usd, alpha=0.50,color='g')
plt.xlabel("Goal")
plt.ylabel("Pledged")
plt.title("Relationship betwenn the Goal and Pledged")

# Draw a trendline on the scatter plot.
z = np.polyfit(dfg.usd_pledged, dfg.goal_usd, 1)
p = np.poly1d(z)
plt.plot(dfg.usd_pledged,p(dfg.usd_pledged),"r-")

plt.show()

# %% [markdown]
# For all project, the usd pledged and the usd goal doesn't have a strong relationship.

# %% [markdown]
# ## Part 4: Inference

# %% [markdown]
# ### 1.  How different country behave differently in success rate

# %%
# Slice the series with suceess rate of different countries
Succ_num = (df[df['status']=='successful']['country'])
Total_num = (df['country'])
Succ_rate = Succ_num.value_counts()/Total_num.value_counts()

# %%
# Turn series into dataframe and then fix the header name
dfs=Succ_rate.to_frame(name='Success rate')
dfs.rename(index=str,columns={"index": "country", "Success rate": "succ_rate"}, inplace=True)
df1 = dfs.reset_index()
df2 = df1.sort_values(by='succ_rate', ascending=False)

# %%
# make the barplot of Different success Rate of different countries
ax = sns.barplot(x="index", y="succ_rate", data=df2)
ax.set(xlabel="Country", ylabel="Success Rate");

# %% [markdown]
# Use matplotblib to make a bar plot same as the one above.

# %%
# Slice the series with suceess rate of different countries
Succ_num = (df[df['status']=='successful']['country'])
Total_num = (df['country'])
Succ_rate = Succ_num.value_counts()/Total_num.value_counts()
ssr= Succ_rate.sort_values(ascending=False)

# Turn series into dataframe and then fix the header name
dfs=ssr.to_frame(name='Success rate')
dfs.rename(index=str,columns={"index": "country", "Success rate": "succ_rate"}, inplace=True)
dfs.reset_index()

# make the barplot use the matplotlib met
plt.figure(1)

plt.bar(dfs.index,dfs.succ_rate, alpha=0.75,color='g')
plt.xlabel("country")
plt.ylabel("success rate")

plt.show()

# %% [markdown]
# According to the bar plots above, the country or area with the highest success rate is Hongkong, the country or area with the lowest success rate is Italia. The U.S. is the sixth country in terms of success rate. The success rate is close to 80 percent for Hongkong, less than 40 percent for Italia and close to 65 percent for the U.S.

# %% [markdown]
# ### 2.Is there any relationship between the goal amount and pledged amount among the succeed cases？

# %% [markdown]
# Use the seaborn to draw a scatterplot.

# %%
# Slice the series of 'usd_pledged', and 'goal_usd' within successful cases.
df3 = df[df['status']=='successful']
df3[['usd_pledged','goal_usd']]
df3.head(5)

# Draw a scatter plot use seaborn 'sns.lmplot' function.
bx = sns.lmplot(x= 'usd_pledged', y='goal_usd', data=df3)
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Use the matplotlin to draw a scatterplot.

# %%
# Setup the figue.
plt.figure(1)

# Draw a scatter plot with x = 'usd_pledged', and y = 'goal_usd' 
plt.scatter(df3.usd_pledged,df3.goal_usd, alpha=0.50,color='g')
plt.xlabel("Goal")
plt.ylabel("Pledged")
plt.title("Relationship betwenn the Goal and Pledged")

# Draw a trendline on the scatter plot.
z = np.polyfit(df3.usd_pledged, df3.goal_usd, 1)
p = np.poly1d(z)
plt.plot(df3.usd_pledged,p(df3.usd_pledged),"r-")

plt.show()

# %% [markdown]
# The scatter plots above show a strong positive relationship between the goal amount and the pledged amount. This founding does agree with the correlation statement we made before. After the investigation, we understand that the reason that the correlation table doesn't show the strong relationship between the goal amount and the pledged amount is the effect of the failed cases. Once the failed cases have been eliminated, the more valid relationship between these two variables shown up.

# %% [markdown]
# ### 3. How Main Category Perform differently on average amount of usd pledged ending in different quarter?

# %%
# Creating a dataframe with the mean of usd pledged of each main category
df5 = df3[['main_category','usd_pledged','end_Q']].round()
pt = df5.pivot_table(index='main_category', columns='end_Q', values='usd_pledged', aggfunc=np.sum)
pt.head()
# Out:
# end_Q                  Q1          Q2          Q3          Q4
# main_category
# art            15035583.0  20307427.0  21636955.0  20149762.0
# comics         12338827.0  18203929.0  19026383.0  22388309.0
# crafts          3691131.0   4705654.0   4862079.0   6756620.0
# dance           3689870.0   4874962.0   4655600.0   4695439.0
# design         44700691.0  86422781.0  85107968.0  91144432.0

# %% [markdown]
# Use the seaborn to draw a heatmap

# %%
# creating heatmap of Usd pledged per Main category and End Quarter
f, ax = plt.subplots(figsize = (16, 8))
cmap = sns.cubehelix_palette(start = 1, rot = 3, gamma=1, as_cmap = True)
sns.heatmap(pt, cmap = cmap, linewidths = 1, ax = ax)
ax.set_title('Usd Pledged per Main Category and End Quarter ')
ax.set_xlabel('end_Q')
ax.set_ylabel('main_category')
# Out:
# Text(123,0.5,'main_category')

# %% [markdown]
# Use the matplotlin to draw a heatmap

# %%
# creating heatmap of Usd pledged per Main category and End Quarter
plt.subplots(figsize = (16, 8))
ax = sns.heatmap(pt, linewidth=0.5)
plt.show()

# %% [markdown]
# The heat-maps above show the main category that pledged most on average is technology. For this specific category, the best ending time should be Q2 and Q4 which those projects usually pledged most on average. On the other hands, the category of design, film & video, games are also performed much better in Q2 to Q4 so that this time period is also great to end a project. However, for other category, this tendency is weak.

# %% [markdown]
# ## Part 5: Conclusion

# %% [markdown]
# In general, the country or area with the highest success rate is Hong Kong. The overall relationship between the goal amount and the pledged amount is not strong at all. Once the failed cases have been eliminated, a strong and positive relationship between these two variables shown up.The main category that pledged most on average is technology and the best time to end is Q4.
